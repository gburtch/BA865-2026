# %% [markdown]
# # Import Our Data

# %% [markdown]
# Save the data to your Google Drive. Then you can mount your drive and access the folder from wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.
#
# Note: the dog-cat classifier datasets are under "5_Mar 31" (last week's material)

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2026/5_Mar 31/dogs-vs-cats/"

train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

keras.utils.plot_model(model,show_shapes=True,dpi=60)

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="Xception.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 180, 180, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential (Sequential)   │ (None, 180, 180, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 180, 180, 3)    │              0 │ sequential[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 176, 176, 32)   │          2,400 │ rescaling[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 176, 176, 32)   │            128 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 176, 176, 32)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 176, 176, 32)   │          1,312 │ activation[0][0]       │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 176, 176, 32)   │            128 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 176, 176, 32)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 176, 176, 32)   │          1,312 │ activation_1[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 88, 88, 32)     │              0 │ separable_conv2d_1[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 88, 88, 32)     │          1,024 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 88, 88, 32)     │              0 │ max_pooling2d[0][0],   │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 88, 88, 32)     │            128 │ add[0][0]              │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 88, 88, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 88, 88, 64)     │          2,336 │ activation_2[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 88, 88, 64)     │            256 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 88, 88, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 88, 88, 64)     │          4,672 │ activation_3[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 44, 44, 64)     │              0 │ separable_conv2d_3[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 44, 44, 64)     │          2,048 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 44, 44, 64)     │              0 │ max_pooling2d_1[0][0], │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 44, 44, 64)     │            256 │ add_1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 44, 44, 64)     │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 44, 44, 128)    │          8,768 │ activation_4[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 44, 44, 128)    │            512 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 44, 44, 128)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 44, 44, 128)    │         17,536 │ activation_5[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 22, 22, 128)    │              0 │ separable_conv2d_5[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 22, 22, 128)    │          8,192 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 22, 22, 128)    │              0 │ max_pooling2d_2[0][0], │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 22, 22, 128)    │            512 │ add_2[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 22, 22, 128)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 22, 22, 256)    │         33,920 │ activation_6[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 22, 22, 256)    │          1,024 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 22, 22, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 22, 22, 256)    │         67,840 │ activation_7[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 11, 11, 256)    │              0 │ separable_conv2d_7[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 11, 11, 256)    │         32,768 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 11, 11, 256)    │              0 │ max_pooling2d_3[0][0], │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 11, 11, 256)    │          1,024 │ add_3[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 11, 11, 256)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 11, 11, 512)    │        133,376 │ activation_8[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 11, 11, 512)    │          2,048 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 11, 11, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 11, 11, 512)    │        266,752 │ activation_9[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 6, 6, 512)      │              0 │ separable_conv2d_9[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 6, 6, 512)      │        131,072 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 6, 6, 512)      │              0 │ max_pooling2d_4[0][0], │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ add_4[0][0]            │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1)              │            513 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 721,857 (2.75 MB)
#  Trainable params: 718,849 (2.74 MB)
#  Non-trainable params: 3,008 (11.75 KB)

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5066 - loss: 0.7242 - val_accuracy: 0.5300 - val_loss: 0.6924
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.5852 - loss: 0.6627 - val_accuracy: 0.5350 - val_loss: 0.6917
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6547 - loss: 0.6281 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6881 - loss: 0.5922 - val_accuracy: 0.5000 - val_loss: 0.6937
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.6928 - loss: 0.5897 - val_accuracy: 0.5050 - val_loss: 0.6915
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6506 - loss: 0.6067 - val_accuracy: 0.5125 - val_loss: 0.6947
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6823 - loss: 0.5874 - val_accuracy: 0.5025 - val_loss: 0.6952
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7160 - loss: 0.5694 - val_accuracy: 0.5000 - val_loss: 0.6941
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6907 - loss: 0.5733 - val_accuracy: 0.5025 - val_loss: 0.6962
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6469 - loss: 0.6165 - val_accuracy: 0.5000 - val_loss: 0.7066
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6840 - loss: 0.5866 - val_accuracy: 0.5000 - val_loss: 0.7597
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7219 - loss: 0.5468 - val_accuracy: 0.5000 - val_loss: 0.7109
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7421 - loss: 0.5209 - val_accuracy: 0.5000 - val_loss: 0.7709
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7550 - loss: 0.5194 - val_accuracy: 0.5000 - val_loss: 0.7396
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7368 - loss: 0.5498 - val_accuracy: 0.5000 - val_loss: 0.7860
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7712 - loss: 0.4878 - val_accuracy: 0.5000 - val_loss: 0.8795
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7099 - loss: 0.5250 - val_accuracy: 0.5100 - val_loss: 0.8894
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7664 - loss: 0.4849 - val_accuracy: 0.5150 - val_loss: 0.9385
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7606 - loss: 0.4904 - val_accuracy: 0.5675 - val_loss: 0.7561
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7763 - loss: 0.4796 - val_accuracy: 0.5075 - val_loss: 1.0561
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7801 - loss: 0.4382 - val_accuracy: 0.5500 - val_loss: 0.9926
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.7932 - loss: 0.4344 - val_accuracy: 0.6625 - val_loss: 0.6374
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.7864 - loss: 0.4530 - val_accuracy: 0.7225 - val_loss: 0.6081
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8170 - loss: 0.4141 - val_accuracy: 0.6900 - val_loss: 0.6280
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8100 - loss: 0.4218 - val_accuracy: 0.6575 - val_loss: 0.6861
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8144 - loss: 0.4129 - val_accuracy: 0.6650 - val_loss: 0.6649
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8207 - loss: 0.3968 - val_accuracy: 0.7800 - val_loss: 0.5665
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8387 - loss: 0.3716 - val_accuracy: 0.5975 - val_loss: 1.2006
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8033 - loss: 0.4172 - val_accuracy: 0.5200 - val_loss: 1.4543
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8188 - loss: 0.3602 - val_accuracy: 0.6550 - val_loss: 1.0437
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8460 - loss: 0.3604 - val_accuracy: 0.6775 - val_loss: 0.8672
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8381 - loss: 0.3587 - val_accuracy: 0.6200 - val_loss: 1.0351
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8536 - loss: 0.3619 - val_accuracy: 0.6925 - val_loss: 0.7499
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8545 - loss: 0.3673 - val_accuracy: 0.7200 - val_loss: 0.8951
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8437 - loss: 0.3590 - val_accuracy: 0.6125 - val_loss: 1.2408
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8706 - loss: 0.3042 - val_accuracy: 0.7150 - val_loss: 0.5757
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8466 - loss: 0.3258 - val_accuracy: 0.7700 - val_loss: 0.5922
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8433 - loss: 0.3510 - val_accuracy: 0.7500 - val_loss: 0.5802
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8726 - loss: 0.3008 - val_accuracy: 0.6900 - val_loss: 0.8212
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8863 - loss: 0.2569 - val_accuracy: 0.7850 - val_loss: 0.6309
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8749 - loss: 0.2862 - val_accuracy: 0.7500 - val_loss: 0.8847
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8832 - loss: 0.2658 - val_accuracy: 0.7650 - val_loss: 0.5753
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8681 - loss: 0.2812 - val_accuracy: 0.6850 - val_loss: 0.8667
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9125 - loss: 0.2402 - val_accuracy: 0.7300 - val_loss: 0.9252
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8974 - loss: 0.2285 - val_accuracy: 0.6525 - val_loss: 1.0207
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8613 - loss: 0.3553 - val_accuracy: 0.7500 - val_loss: 1.3242
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8640 - loss: 0.3177 - val_accuracy: 0.6975 - val_loss: 0.9350
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9096 - loss: 0.2316 - val_accuracy: 0.6625 - val_loss: 1.1021
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8993 - loss: 0.2559 - val_accuracy: 0.6900 - val_loss: 0.7730
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8913 - loss: 0.2478 - val_accuracy: 0.7300 - val_loss: 0.6894
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9210 - loss: 0.2168 - val_accuracy: 0.7525 - val_loss: 0.6268
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8627 - loss: 0.3092 - val_accuracy: 0.6550 - val_loss: 1.3637
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8982 - loss: 0.2586 - val_accuracy: 0.7750 - val_loss: 0.5378
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8918 - loss: 0.2806 - val_accuracy: 0.7825 - val_loss: 0.5720
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9178 - loss: 0.1965 - val_accuracy: 0.5900 - val_loss: 1.5515
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8929 - loss: 0.2432 - val_accuracy: 0.7100 - val_loss: 0.8603
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9173 - loss: 0.2428 - val_accuracy: 0.7225 - val_loss: 0.8866
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9153 - loss: 0.2273 - val_accuracy: 0.7500 - val_loss: 0.6583
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9097 - loss: 0.1975 - val_accuracy: 0.7600 - val_loss: 0.6701
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9381 - loss: 0.1775 - val_accuracy: 0.7400 - val_loss: 0.7093
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9196 - loss: 0.1869 - val_accuracy: 0.7800 - val_loss: 0.7474
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9045 - loss: 0.2188 - val_accuracy: 0.7650 - val_loss: 0.6784
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9272 - loss: 0.1752 - val_accuracy: 0.7450 - val_loss: 0.6983
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9461 - loss: 0.1569 - val_accuracy: 0.6025 - val_loss: 2.4306
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9441 - loss: 0.1447 - val_accuracy: 0.7700 - val_loss: 1.0442
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9301 - loss: 0.1692 - val_accuracy: 0.7375 - val_loss: 0.7584
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9327 - loss: 0.1879 - val_accuracy: 0.6950 - val_loss: 0.8722
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9206 - loss: 0.2170 - val_accuracy: 0.6275 - val_loss: 1.7821
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9275 - loss: 0.1772 - val_accuracy: 0.7900 - val_loss: 0.6263
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9455 - loss: 0.1367 - val_accuracy: 0.7650 - val_loss: 0.6584
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9363 - loss: 0.1474 - val_accuracy: 0.7650 - val_loss: 0.8173
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9378 - loss: 0.1533 - val_accuracy: 0.6725 - val_loss: 1.9503
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9433 - loss: 0.1591 - val_accuracy: 0.7400 - val_loss: 0.9081
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9474 - loss: 0.1490 - val_accuracy: 0.6900 - val_loss: 0.8671
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9132 - loss: 0.1987 - val_accuracy: 0.7775 - val_loss: 0.8362
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9356 - loss: 0.1550 - val_accuracy: 0.7725 - val_loss: 0.6417
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9389 - loss: 0.1602 - val_accuracy: 0.7875 - val_loss: 0.6064
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9429 - loss: 0.1295 - val_accuracy: 0.6900 - val_loss: 1.3139
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9302 - loss: 0.1515 - val_accuracy: 0.7775 - val_loss: 0.7642
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9135 - loss: 0.1953 - val_accuracy: 0.6975 - val_loss: 1.4232
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9391 - loss: 0.1502 - val_accuracy: 0.8000 - val_loss: 0.6657
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9425 - loss: 0.1373 - val_accuracy: 0.7500 - val_loss: 1.0490
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9274 - loss: 0.2044 - val_accuracy: 0.8200 - val_loss: 0.5791
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9212 - loss: 0.1652 - val_accuracy: 0.7850 - val_loss: 0.6118
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9444 - loss: 0.1310 - val_accuracy: 0.8050 - val_loss: 0.5628
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9527 - loss: 0.1364 - val_accuracy: 0.7625 - val_loss: 0.6014
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9498 - loss: 0.1342 - val_accuracy: 0.7150 - val_loss: 1.1684
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9487 - loss: 0.1430 - val_accuracy: 0.7775 - val_loss: 0.7514
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9555 - loss: 0.1207 - val_accuracy: 0.7500 - val_loss: 0.8918
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9428 - loss: 0.1428 - val_accuracy: 0.7925 - val_loss: 0.8121
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9662 - loss: 0.1285 - val_accuracy: 0.7575 - val_loss: 0.6791
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9297 - loss: 0.1477 - val_accuracy: 0.8050 - val_loss: 0.5884
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9633 - loss: 0.1084 - val_accuracy: 0.7850 - val_loss: 0.9410
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9609 - loss: 0.0933 - val_accuracy: 0.7475 - val_loss: 1.1981
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9467 - loss: 0.1468 - val_accuracy: 0.7325 - val_loss: 0.9797
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9641 - loss: 0.1170 - val_accuracy: 0.7950 - val_loss: 0.6067
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9568 - loss: 0.1022 - val_accuracy: 0.7925 - val_loss: 0.6376
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9459 - loss: 0.1490 - val_accuracy: 0.6325 - val_loss: 1.8348
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9458 - loss: 0.1493 - val_accuracy: 0.7850 - val_loss: 0.7417
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9788 - loss: 0.0730 - val_accuracy: 0.7800 - val_loss: 0.8582

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we can now reach ~75% accuracy with 100 epochs of learning...

# %%
test_model = keras.models.load_model("Xception.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 887ms/step - accuracy: 0.7435 - loss: 0.6744
# Test accuracy: 0.7631579041481018
